# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Date_Fruit_Datasets.csv")

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2)

# %%
AdaBoost=AdaBoostClassifier(n_estimators=100,learning_rate=1)

# %%
model=AdaBoost.fit(X_train,Y_train)
y_pred=model.predict(X_test)

# %%
print("Accuracy: ",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy:  0.6833333333333333

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier


adaboost_classifier = AdaBoostClassifier(
    n_estimators=50,
    learning_rate=1,
    random_state=42
)

model = adaboost_classifier.fit(X_train, Y_train)

# %%
for p in range(20,30):
    base_classifier = AdaBoostClassifier(n_estimators=p)
    y_base_pred = base.predict(X_test)
    print("estimators : ",p,"Accuracy: ",accuracy_score(Y_test,y_base_pred))
# Out:
# estimators :  20 Accuracy:  0.7833333333333333
# estimators :  21 Accuracy:  0.7833333333333333
# estimators :  22 Accuracy:  0.7833333333333333
# estimators :  23 Accuracy:  0.7833333333333333
# estimators :  24 Accuracy:  0.7833333333333333
# estimators :  25 Accuracy:  0.7833333333333333
# estimators :  26 Accuracy:  0.7833333333333333
# estimators :  27 Accuracy:  0.7833333333333333
# estimators :  28 Accuracy:  0.7833333333333333
# estimators :  29 Accuracy:  0.7833333333333333

# %%
y_pred=model.predict(X_test)

# %%
print("Accuracy: ",accuracy_score(Y_test,y_base_pred))
# Out:
# Accuracy:  0.7833333333333333

# %%
print("Accuracy: ",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy:  0.6833333333333333

# %%
accuracies = []
estimator_counts = list(range(1, 101)) 

for n_estimators in estimator_counts:
    adaboost_classifier = AdaBoostClassifier(
        n_estimators=n_estimators,
        learning_rate=1,
        random_state=42
    )
    
    model = adaboost_classifier.fit(X_train, Y_train)
    
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(Y_test, y_pred)
    accuracies.append(accuracy)

plt.figure(figsize=(10, 6))
plt.plot(estimator_counts, accuracies, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Estimators for AdaBoost')
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
